# %%
import sqlite3, pandas as pd

# %%
con = sqlite3.connect('src/datasets/etlbcb.db')
query = "SELECT * FROM meios_pagamentos_tri"
df = pd.read_sql(query,con)

# %%
df
# Out:
#           datatrimestre    valorPix     valorTED  valorTEC  valorCheque  \
# 0   2024-12-31 00:00:00  7714115.37  11647265.67      0.00    187486.45
# 1   2024-09-30 00:00:00  6975429.47  11180217.68      0.00    194330.60
# 2   2024-06-30 00:00:00  6284296.05  10662555.73      0.00    221553.82
# 3   2024-03-31 00:00:00  5429305.43   9651625.56    925.26    190457.25
# 4   2023-12-31 00:00:00  5300155.00  10090921.81   5787.89    221424.78
# 5   2023-09-30 00:00:00  4469529.57   9960251.89   4156.38    218121.88
# 6   2023-06-30 00:00:00  3900377.43  10657463.13   4770.74    228408.82
# 7   2023-03-31 00:00:00  3447198.28   9919602.84   4535.17    240686.19
# 8   2022-12-31 00:00:00  3342913.94  10382121.63   5609.53    242259.61
# 9   2022-09-30 00:00:00  2936413.95  10437763.16   3735.46    267090.22
# 10  2022-06-30 00:00:00  2543384.40  10449574.67   4786.14    271008.09
# 11  2022-03-31 00:00:00  2067826.55   9507158.34   3865.81    255455.43
# ...

# %%
soma_valorPix = df['valorPix'].sum()*1e6
total_valorPix = df['valorPix'].count()

print("Média das transações de PIX por trimestre: ",round(soma_valorPix/total_valorPix,2))
# Out:
# Média das transações de PIX por trimestre:  2490206540416.67

# %%
soma_valores = df['valorPix'].sum()*1e6
soma_transacoes = df['quantidadePix'].sum()*1e3

soma_valores/soma_transacoes
# Out:
# np.float64(430.713035665615)

# %%
df['valorPix'].mean()*1e6
# Out:
# np.float64(2490206540416.667)

# %%
soma1 = df['valorPix'].mean()*1e3
soma2 = df['quantidadePix'].mean()

soma1/soma2
# Out:
# np.float64(430.71303566561505)

# %%
df['valorPix']/df['quantidadePix']
# Out:
# 0     0.429496
# 1     0.421567
# 2     0.409217
# 3     0.399935
# 4     0.406277
# 5     0.402046
# 6     0.415085
# 7     0.424720
# 8     0.428185
# 9     0.449777
# 10    0.466895
# 11    0.486545
# 12    0.499551
# 13    0.543742
# 14    0.590808
# 15    0.724828
# 16    0.850677
# 17         NaN
# 18         NaN
# 19         NaN
# 20         NaN
# 21         NaN
# 22         NaN
# 23         NaN
# dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 27 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   datatrimestre                 24 non-null     object
#  1   valorPix                      24 non-null     float64
#  2   valorTED                      24 non-null     float64
#  3   valorTEC                      24 non-null     float64
#  4   valorCheque                   24 non-null     float64
#  5   valorBoleto                   24 non-null     float64
#  6   valorDOC                      24 non-null     float64
#  7   valorCartaoCredito            24 non-null     float64
#  8   valorCartaoDebito             24 non-null     float64
#  9   valorCartaoPrePago            24 non-null     float64
#  10  valorTransIntrabancaria       24 non-null     float64
#  11  valorConvenios                24 non-null     float64
# ...

# %%
#Média para valores TED

soma1 = df['valorTED'].mean()*1e3
soma2 = df['quantidadeTED'].mean()

soma1/soma2

# %%
#Média para valores TEC

soma1 = df['valorTEC'].mean()*1e3
soma2 = df['quantidadeTEC'].mean()

soma1/soma2

# %%
#Média para valores de Cheque

soma1 = df['valorCheque'].mean()*1e3
soma2 = df['quantidadeCheque'].mean()

soma1/soma2

# %%
#Média para valores de Boleto

soma1 = df['valorBoleto '].mean()*1e3
soma2 = df['quantidadeBoleto '].mean()

soma1/soma2

# %%
#Média para valores DOC                      

soma1 = df['valorDOC'].mean()*1e3
soma2 = df['quantidadeDOC'].mean()

soma1/soma2

# %%
#Média para valores de cartão de crédito                      

soma1 = df['valorCartaoCredito'].mean()*1e3
soma2 = df['quantidadeCartaoCredito'].mean()

soma1/soma2

# %%
#Média para valores de cartão de débito                      

soma1 = df['valorCartaoDebito'].mean()*1e3
soma2 = df['quantidadeCartaoDebito'].mean()

soma1/soma2
 13  valorSaques

# %%
#Média para valores de cartão pré pago                      

soma1 = df['valorCartaoPrePago'].mean()*1e3
soma2 = df['quantidadeCartaoPrePago'].mean()

soma1/soma2

# %%
#Média para valores de transação intra bancária                      

soma1 = df['valorTransIntrabancaria'].mean()*1e3
soma2 = df['quantidadeTransIntrabancaria'].mean()

soma1/soma2

# %%
#Média para valores de convenios                    

soma1 = df['valorConvenios'].mean()*1e3
soma2 = df['quantidadeConvenios'].mean()

soma1/soma2

# %%
#Média para valores de debitos diretos                    

soma1 = df['valorDebitoDireto'].mean()*1e3
soma2 = df['quantidadeDebitoDireto'].mean()

soma1/soma2
# Out:
# np.float64(316.9388188344725)

# %%
#Média para valores de saques                  

soma1 = df['valorSaques'].mean()*1e3
soma2 = df['quantidadeSaques'].mean()

soma1/soma2
# Out:
# np.float64(761.4387300101117)
